# %% [markdown]
# ## Input Fungtion

# %%
data = 'Data science is fun'

# %%
data
# Out:
# 'Data science is fun'

# %%
type(data)
# Out:
# str

# %%
data1 = input()
# Out:
#  data science is fun

# %%
data1
# Out:
# 'data science is fun'

# %%
x=input()
y=input()
# Out:
#  2
#  3

# %%
x+y
# Out:
# '23'

# %%
x=int(x)
y=int(y)

# %%
x+y
# Out:
# 5

# %%
y=int(input('Enter your first number: '))
# Out:
# Enter your first number:  56

# %%
z=float(input('Enter your 2nd number: '))
# Out:
# Enter your 2nd number:  26.5

# %%
y+z
# Out:
# 82.5

# %%
a=int(input('Enter your first number: '))
b= int (input('Enter your 2nd number: '))
print('The summetion of the two number is: ', a+b);
print('The subtraction of the two number is: ', a-b);
print('The Multiplication of the two number is: ', a*b);
print('The divition of the two number is: ', a/b)
# Out:
# Enter your first number:  2556
# Enter your 2nd number:  656
# The summetion of the two number is:  3212
# The subtraction of the two number is:  1900
# The Multiplication of the two number is:  1676736
# The divition of the two number is:  3.8963414634146343

# %% [markdown]
# ## String

# %%
data= "60 days of python"

# %%
type(data)
# Out:
# str

# %%
len(data)
# Out:
# 17

# %%
import sys
sys.getsizeof(data)
# Out:
# 58

# %%
data.count("python")
# Out:
# 1

# %%
sub='days of'

# %%
data.count(sub)
# Out:
# 1
