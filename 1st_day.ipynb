# %%
print('hellow')
# Out:
# hellow

# %%
3+3
# Out:
# 6

# %%
#This is the numer which is alter without any input
a=78
b=34
a,b = b,a
print(a,b)
# Out:
# 34 78

# %% [markdown]
# n1= 10
# n2= 8
# n3 = 3
#
# N = n1+n2+n3 #TotaL Vote
#
# half=N/2
# eighth = N/8
# leader = max(n1,n2,n3)
# # candidate 1
# print('Candidate 1:')
# if n1>half:
#    print('Elected in the first Round')
# elif half> n1>=eighth:
#    print('In the second round')
# else:
#     print('Not elected')
#
# # candidate 2
# print('Candidate 2:')
# if n1>half:
#    print('Elected in the first Round')
# elif half> n1>=eighth:
#    print('In the second round')
# else:
#     print('Not elected')
#
# # candidate 3
# print('Candidate 3:')
# if n2>half:
#    print('Elected in the first Round')
# elif half> n2>=eighth:
#    print('In the second round')
# else:
#     print('Not elected')
