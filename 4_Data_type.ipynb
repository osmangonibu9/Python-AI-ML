# %% [markdown]
# #Python data type
# 1. Numeric
#     a) integer
#     b) float
#     c) complex
# 2. Boolean: T & F
# 3. Sequence
#     a) Lists
#     b) Tuples
#     c) Arrays
#     d) String
#     e) range
# 5. Set
#     a) Frozen
#     b) Set
# 6. Mapping
#     a) Dictionary
# 7.  Data Frame
#     rows & column
# 8. Binary
#     a) Memory View
#     b) Byte Array
#     c) Bytes

# %%
# Numeric
x=10 # int
y= 10.5 # float
z=10+5j # Complex

# %%
type(y)
# Out:
# float

# %%
isinstance(z,complex)
# Out:
# True

# %%
isinstance(10,complex)
# Out:
# False

# %%
# int to float
n= float(x)
n
# Out:
# 10.0

# %%
type(n)
# Out:
# float

# %%
n=int(n)
n
# Out:
# 10

# %%
c=complex(n)
c
# Out:
# (10+0j)

# %%
# Complex to other impossible

# %%
j=complex(input('Enter your complex number: '))
# Out:
# Enter your complex number:  5

# %%
j
# Out:
# (5+0j)

# %%
type(j)
# Out:
# complex

# %%
## Bo
