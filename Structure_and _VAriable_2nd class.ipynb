# %%
print('hellow World', 'This my mother land',  sep=' & ', end=' *') # Run=Shift+Enter # fungtion details=Shift+Tab
# Out:
# hellow World & This my mother land *

# %% [markdown]
# Variable

# %%
v='My name is Osman Goni'
print(v)
# Out:
# My name is Osman Goni

# %%
print(v, ' This is my family name', sep='.')
# Out:
# My name is Osman Goni. This is my family name

# %%
id (v)
# Out:
# 2647030662768

# %%
import sys
sys.getsizeof(v)
# Out:
# 62

# %%
x=100
x
# Out:
# 100

# %%
y=120

# %%
y
# Out:
# 120

# %%
id(y)
# Out:
# 140715890410328

# %%
id(x)
# Out:
# 140715890409688

# %%
name='Osman'

# %%
name
# Out:
# 'Osman'

# %%
x,y,z=10,130,20
z
# Out:
# 20

# %%
#Case sensitive
p=3
P=5
p
# Out:
# 3

# %%
#camelCaseVar
#PascalCaseVar
#snake_case_var

# %%
# Local vs Global
x=1000 # global variable
def func1():
    x=500 # local variable
    print ('My point is : ', x)
func1()
print('My name is :', x)
# Out:
# My point is :  500
# My name is : 1000
