# %%
## condition
x=input(int())
y=input(int())
if y>x:
    print('y is greater than x')
else:
    print('x is greater than y')
# Out:
# 0 50
# 0 100
# x is greater than y

# %%
x=int(input('Enter your first number: '))
# Out:
# Enter your first number:  50

# %%
x=int(input('Enter your first number: '))
if x>80:
    print("A+") # must use tab
elif 70<x<=80:
    print('A')
elif 60<x<=70:
    print('B')
elif 50<x<=60:
    print('C')
elif 40<x<=50:
    print('D')
else:
    print ('F')
# Out:
# Enter your first number:  81
# A+

# %%
### Nested means one inside another.

# %%
# Indention rules 
# Block1
    # Block2
        #Block3
        #Block3
    #Block2
#Block1

# %%
# Q:: Take values of length and bradth of a rectangle from user input() and check it is Square or not?

L=float(input('Enter the length value: '))
B=float(input('Enter the breadh value: '))
if L*B==L**2:
    print('This is a square')
else: 
    print ('This is not a square')
# Out:
# Enter the length value:  5
# Enter the breadh value:  5
# This is a square

# %%
s = 20
w = 30

if s > w:
    print("s is greater")
elif w > s:
    print('w is greater')
    print("This is true")
    if s != w:
        print("Both are not equal")
else:
    print('out!')
# Out:
# w is greater
# This is true
# Both are not equal

# %%
num= float (input('Enter any number'))
if num % 2==0:
    if num % 5==0:
        print(num, ' Divisible bt 5 and 2')
    else:
        print('no 1')
else:
    print('No 2')
# Out:
# Enter any number 8
# no 1

# %%
from IPython.display import Image
Image('Image.jpg')

# %%
# Q1:Solve
amount= 0
net_unit= float(input(' Enter your unit value : '))
if 0< net_unit<=100:
    amount= 0
elif net_unit> 100 and net_unit <=200:
    amount= (net_unit-100)*5
elif net_unit>200:
    amount= ((200-100)*5)+((net_unit-200)*10)
print('Amount is ', amount)
# Out:
#  Enter your unit value :  250
# Amount is  1000.0

# %%
b = frozenset('asdfagsa')
print(b)
# Out:
# frozenset({'g', 'd', 's', 'a', 'f'})

# %%
cities = frozenset(["Frankfurt", "Basel","Freiburg"])
print(cities)
# Out:
# frozenset({'Frankfurt', 'Basel', 'Freiburg'})

# %%
from IPython.display import Image
Image('Image/Screenshot_2026-02-01-21-11-15-81.jpg')

# %%
# Q1: Solve
length= float(input('Enter the length value: '))
breadth= float(input('Enter the breadth value: '))
if length==breadth:
    print ('This is a square')
else:
    print('This is not a square')
# Out:
# Enter the length value:  5
# Enter the breadth value:  25
# This is not a square

# %%
# Q2: Solve
a=float(input('Enter the first value: '))
b= float(input('Enter the second value: '))
c= float(input('Enter the third value: '))
if b<a>c:
    highest=a
elif a<b>c:
    highest=b
else:
    highest=c
print (highest,'is the highest value among three number')
# Out:
# Enter the first value:  25
# Enter the second value:  45
# Enter the third value:  62
# 62.0 is the highest value among three number

# %%
# Q3: Solve
total_class=int(input(' Enter the total class number:= '))
attendencec= int(input(' Enter the number of class attendence:= '))
percentege= (attendencec/total_class)*100
gender=input(' Enter Male=M or Female=F :=')
if percentege>=75:
    if gender=='M':
        print('He will allowed to sit in Exam')
    else:
        print('She will allowed to sit in Exam')
else:
    if gender=='M':
        print('He will not allowed to sit in Exam')
    else:
        print('She will not allowed to sit in Exam')
# Out:
#  Enter the total class number:=  50
#  Enter the number of class attendence:=  24
#  Enter Male=M or Female=F := F
# She will not allowed to sit in Exam
