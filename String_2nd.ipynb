# %% [markdown]
# ## Python String Method

# %% [markdown]
# ### find fungtion

# %%
data='60 Days of python'

# %%
data.find('of')
# Out:
# 8

# %%
data.find('f')
# Out:
# 9

# %%
data.find('y',6,13)
# Out:
# 12

# %% [markdown]
# ### index fungtion

# %%
data.index('y',6,13)
# Out:
# 12

# %% [markdown]
# ###### The difference between index and find fungtion is if your value is out of range shows error in index fungtion but find fungtion its provide -1

# %%
data.lower()
# Out:
# '60 days of python'

# %%
data.upper()
# Out:
# '60 DAYS OF PYTHON'

# %%
data.casefold()
# Out:
# '60 days of python'

# %%
x='this is my brother'
x.capitalize() # convert only first letter into capital letter
# Out:
# 'This is my brother'

# %%
x.swapcase() # convert into opposite
# Out:
# 'THIS IS MY BROTHER'

# %%
x.title()
# Out:
# 'This Is My Brother'

# %%
x.islower()
# Out:
# True

# %%
x.isupper()
# Out:
# False

# %%
x.isdigit()
# Out:
# False

# %%
x.encode()
# Out:
# b'this is my brother'

# %%
type(x.encode())
# Out:
# bytes

# %%
x
# Out:
# 'this is my brother'

# %%
x.split()
# Out:
# ['this', 'is', 'my', 'brother']

# %%
x.split()[1]
# Out:
# 'is'

# %%
x.center(50)
# Out:
# '                this is my brother                '

# %%
x.replace('this','This')
# Out:
# 'This is my brother'

# %%
x=10
y=23
z=x*y
print("I have ", z,"taka")
# Out:
# I have  230 taka

# %%
print('I have {} taka',format(z))
# Out:
# I have {} taka 230
