# %% [markdown]
# ## Operaators in Python

# %% [markdown]
# ### Python Arithmetic Operator
# Addition=+
# Subtraction= -
# Multiplication=*
# Division=/
# Modulus=%
# Exponentiation= **
# Floor Division=//
#
# ### Python Identity operator
# is= Return true if both variable are the same object.
# is not = Returns true if both variable are not the same object
# is usually use to check the location of any value
#
# ### Pyton Bitwise Operator
#
# AND=&
# OR=|
# XOR=^
# NOT=~
# Zero fill left shift= <<
# Signed right shift= >>
#
# ### Python Comaparison Operators
#
# Equal     ==
# Not Equal  !=
# Greater than >
# Less than <
# Greter than or equal to   >=
# Less than or equal to    <=
#
# ### Python logical Operations
#
# and= Returns True if both statement are  equal
# or= Returns True if one statements is true
# not= Reverse the result , returns False if the result is true
#
# ### Python ASsignment Operators
#
# =
# +=  x+= 10 means x= x+10
# -=  x-=10 means x= x-10

# %%
## Arithmetic Operator
x=15
y=4
z=3

# %%
x+y
# Out:
# 19

# %%
x-y
# Out:
# 11

# %%
x/y
# Out:
# 3.75

# %%
x*y
# Out:
# 60

# %%
4**2
# Out:
# 16

# %%
x**y
# Out:
# 50625

# %%
x//y
# Out:
# 3

# %%
import math
math.floor(x/y)
# Out:
# 3

# %%
math.ceil(x/y)
# Out:
# 4

# %%
## Python identity operator
x=10
y=10
x is y
# Out:
# True

# %%
x==y # comperison
# Out:
# True

# %%
x=100017
y=x
z=100017
x is y
# Out:
# True

# %%
x is z
# Out:
# False

# %%
id(x)
# Out:
# 2365983236528

# %%
id(y)
# Out:
# 2365983236528

# %%
id(z)
# Out:
# 2365982662896

# %%
x is z # Based on id or location
# Out:
# False

# %%
x==z ## Based on comperison
# Out:
# True

# %%
## Membership operator
list1=[1,2,3,4,5,6]
1 in list1
# Out:
# True

# %%
10 in list1
# Out:
# False

# %%
10 not in list1
# Out:
# True

# %%
s1={1,2,3,4}
1 in s1
# Out:
# True

# %%
st1='Learn Data Science'
'data' in st1
# Out:
# False

# %%
"Data" in st1
# Out:
# True

# %%
## Bitwyse operator
x=1010 #10 decimal value
y= 101 #5
x | y = 1111
x & y= 0000
# Out:
#   Cell In[35], line 4
#     x | y = 1111
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
x= 10
y= 5
x| y
# Out:
# 15

# %%
x&y
# Out:
# 0

# %%
10>10
# Out:
# False

# %%
10>=10
# Out:
# True

# %%
10>4 and 10<3
# Out:
# False

# %%
10>4 or 10<3
# Out:
# True

# %%
x=10
x+=4
x
# Out:
# 14
